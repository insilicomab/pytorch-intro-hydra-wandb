# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/cifar10/scripts')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/cifar10/scripts

# %%
# !pip install -q timm wandb
# !pip install -q hydra-core --upgrade
# Out:
#      |████████████████████████████████| 509 kB 14.1 MB/s
#      |████████████████████████████████| 1.8 MB 58.3 MB/s
#      |████████████████████████████████| 157 kB 74.1 MB/s
#      |████████████████████████████████| 181 kB 67.4 MB/s
#      |████████████████████████████████| 63 kB 2.0 MB/s
#      |████████████████████████████████| 157 kB 71.6 MB/s
#      |████████████████████████████████| 157 kB 55.4 MB/s
#      |████████████████████████████████| 157 kB 79.6 MB/s
#      |████████████████████████████████| 157 kB 75.6 MB/s
#      |████████████████████████████████| 157 kB 71.6 MB/s
#      |████████████████████████████████| 157 kB 79.2 MB/s
#      |████████████████████████████████| 156 kB 79.3 MB/s
# ...
#      |████████████████████████████████| 151 kB 16.7 MB/s
#      |████████████████████████████████| 117 kB 71.6 MB/s
#      |████████████████████████████████| 79 kB 9.5 MB/s
# ...

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python train.py
# Out:
# device：cuda
# set random seed
# wandb: Currently logged in as: insilicomab. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.2
# wandb: Run data is saved locally in /content/drive/MyDrive/Colab Notebooks/cifar10/scripts/wandb/run-20220902_010914-2kyx2ry8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run jolly-rain-29
# wandb: ⭐️ View project at https://wandb.ai/insilicomab/pytorch-intro-hydra-wandb
# wandb: 🚀 View run at https://wandb.ai/insilicomab/pytorch-intro-hydra-wandb/runs/2kyx2ry8
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_base_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_base_1k_224_ema.pth
# Epoch: 1 / 50
# --------------------------
# train Loss: 0.7895 Accuracy: 0.7536
# val Loss: 0.3159 Accuracy: 0.9008
# Epoch: 2 / 50
# --------------------------
# train Loss: 0.4375 Accuracy: 0.8563
# val Loss: 0.3783 Accuracy: 0.8760
# Epoch: 3 / 50
# --------------------------
# ...

# %%
# !python main.py
# Out:
# device：cuda
# set random seed
# Epoch: 1 / 50
# --------------------------
# train Loss: 0.7895 Accuracy: 0.7536
# val Loss: 0.3159 Accuracy: 0.9008
# Epoch: 2 / 50
# --------------------------
# train Loss: 0.4375 Accuracy: 0.8563
# val Loss: 0.3783 Accuracy: 0.8760
# Epoch: 3 / 50
# --------------------------
# train Loss: 0.3630 Accuracy: 0.8805
# val Loss: 0.3062 Accuracy: 0.9024
# Epoch: 4 / 50
# --------------------------
# train Loss: 0.3012 Accuracy: 0.8992
# val Loss: 0.2985 Accuracy: 0.9048
# Epoch: 5 / 50
# --------------------------
# train Loss: 0.3105 Accuracy: 0.9024
# val Loss: 0.3378 Accuracy: 0.8856
# Epoch: 6 / 50
# --------------------------
# train Loss: 0.2868 Accuracy: 0.9027
# val Loss: 0.4546 Accuracy: 0.8520
# Epoch: 7 / 50
# --------------------------
# train Loss: 0.2866 Accuracy: 0.9029
# val Loss: 0.4878 Accuracy: 0.8520
# Epoch: 8 / 50
# --------------------------
# train Loss: 0.2712 Accuracy: 0.9117
# val Loss: 0.4655 Accuracy: 0.8704
# Epoch: 9 / 50
# ...
