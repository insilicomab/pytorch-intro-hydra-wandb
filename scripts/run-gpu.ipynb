# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/cifar10/scripts')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/cifar10/scripts

# %%
# !pip install -q timm wandb
# !pip install -q hydra-core --upgrade
# Out:
#      |████████████████████████████████| 509 kB 4.0 MB/s
#      |████████████████████████████████| 1.8 MB 48.3 MB/s
#      |████████████████████████████████| 181 kB 61.9 MB/s
#      |████████████████████████████████| 157 kB 68.1 MB/s
#      |████████████████████████████████| 63 kB 1.9 MB/s
#      |████████████████████████████████| 157 kB 62.7 MB/s
#      |████████████████████████████████| 157 kB 68.9 MB/s
#      |████████████████████████████████| 157 kB 72.4 MB/s
#      |████████████████████████████████| 157 kB 73.0 MB/s
#      |████████████████████████████████| 156 kB 73.3 MB/s
#   Building wheel for pathtools (setup.py) ... done
#      |████████████████████████████████| 151 kB 4.2 MB/s
#      |████████████████████████████████| 79 kB 8.0 MB/s
#      |████████████████████████████████| 117 kB 33.4 MB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python main_wb.py
# Out:
# device：cuda
# set random seed
# wandb: Currently logged in as: insilicomab. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.2
# wandb: Run data is saved locally in /content/drive/MyDrive/Colab Notebooks/cifar10/scripts/wandb/run-20220831_085547-3crnweeq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fanciful-shadow-27
# wandb: ⭐️ View project at https://wandb.ai/insilicomab/pytorch-intro-hydra-wandb
# wandb: 🚀 View run at https://wandb.ai/insilicomab/pytorch-intro-hydra-wandb/runs/3crnweeq
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_base_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_base_1k_224_ema.pth
# Epoch: 1 / 50
# --------------------------
# train Loss: 0.8967 Accuracy: 0.7192
# val Loss: 0.2933 Accuracy: 0.9000
# Epoch: 2 / 50
# --------------------------
# train Loss: 0.5093 Accuracy: 0.8245
# val Loss: 0.3348 Accuracy: 0.8920
# Epoch: 3 / 50
# --------------------------
# train Loss: 0.4199 Accuracy: 0.8613
# val Loss: 0.3472 Accuracy: 0.8848
# Epoch: 4 / 50
# --------------------------
# train Loss: 0.4025 Accuracy: 0.8709
# val Loss: 0.3717 Accuracy: 0.8760
# Epoch: 5 / 50
# --------------------------
# train Loss: 0.3798 Accuracy: 0.8701
# val Loss: 0.4291 Accuracy: 0.8672
# Epoch: 6 / 50
# --------------------------
# train Loss: 0.3431 Accuracy: 0.8861
# val Loss: 0.4312 Accuracy: 0.8496
# Epoch: 7 / 50
# --------------------------
# train Loss: 0.3612 Accuracy: 0.8827
# val Loss: 0.3697 Accuracy: 0.8824
# Epoch: 8 / 50
# --------------------------
# train Loss: 0.2946 Accuracy: 0.9000
# val Loss: 0.3504 Accuracy: 0.8936
# Epoch: 9 / 50
# --------------------------
# train Loss: 0.3604 Accuracy: 0.8811
# val Loss: 0.4099 Accuracy: 0.8632
# Epoch: 10 / 50
# --------------------------
# train Loss: 0.2855 Accuracy: 0.9064
# val Loss: 0.3973 Accuracy: 0.8712
# Epoch: 11 / 50
# --------------------------
# train Loss: 0.3099 Accuracy: 0.8979
# val Loss: 0.5597 Accuracy: 0.8344
# Epoch: 12 / 50
# --------------------------
# train Loss: 0.2921 Accuracy: 0.9029
# val Loss: 0.5944 Accuracy: 0.8064
# Epoch: 13 / 50
# --------------------------
# train Loss: 0.3058 Accuracy: 0.8952
# val Loss: 0.4790 Accuracy: 0.8664
# Epoch: 14 / 50
# --------------------------
# train Loss: 0.3368 Accuracy: 0.8853
# val Loss: 0.4493 Accuracy: 0.8584
# Epoch: 15 / 50
# --------------------------
# train Loss: 0.2925 Accuracy: 0.9040
# val Loss: 0.4388 Accuracy: 0.8600
# Epoch: 16 / 50
# --------------------------
# train Loss: 0.2902 Accuracy: 0.9032
# val Loss: 0.4495 Accuracy: 0.8624
# Epoch: 17 / 50
# --------------------------
# train Loss: 0.2544 Accuracy: 0.9133
# val Loss: 0.5871 Accuracy: 0.8352
# Epoch: 18 / 50
# --------------------------
# train Loss: 0.3161 Accuracy: 0.8901
# val Loss: 0.4445 Accuracy: 0.8576
# Epoch 00018: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 19 / 50
# --------------------------
# train Loss: 0.1862 Accuracy: 0.9352
# val Loss: 0.4526 Accuracy: 0.8640
# Epoch: 20 / 50
# --------------------------
# train Loss: 0.1512 Accuracy: 0.9477
# val Loss: 0.4351 Accuracy: 0.8664
# Epoch: 21 / 50
# --------------------------
# train Loss: 0.1174 Accuracy: 0.9613
# val Loss: 0.4295 Accuracy: 0.8672
# Epoch: 22 / 50
# --------------------------
# train Loss: 0.1069 Accuracy: 0.9643
# val Loss: 0.4894 Accuracy: 0.8720
# early stopping
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: train_accuracy ▁▄▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▆▇███
# wandb:     train_loss █▅▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▃▂▁▁▁
# wandb:   val_accuracy █▇▇▆▆▄▇█▅▆▃▁▅▅▅▅▃▅▅▅▆▆
# wandb:       val_loss ▁▂▂▃▄▄▃▂▄▃▇█▅▅▄▅█▅▅▄▄▆
# wandb:
# wandb: Run summary:
# wandb: train_accuracy 0.96427
# wandb:     train_loss 0.10689
# wandb:   val_accuracy 0.872
# wandb:       val_loss 0.48938
# wandb:
# wandb: Synced fanciful-shadow-27: https://wandb.ai/insilicomab/pytorch-intro-hydra-wandb/runs/3crnweeq
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: ./wandb/run-20220831_085547-3crnweeq/logs
